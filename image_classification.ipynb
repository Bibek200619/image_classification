# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibek200619/image_classification/blob/main/image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
mnist = keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(x_train, y_train, epochs=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.fit(x_train, y_train, epochs=3)
#
# NameError: name 'model' is not defined

# %%
test_loss,test_acc = model.evaluate(x_test, y_test)

print("Accuracy:", test_acc)
print("Test lose", test_loss)

# %%
import numpy as np
import random

predictions = model.predict(x_test)
size = random.randint(0,1875)

for i in range(size,size+1):
    print(f"Predicted: {np.argmax(predictions[i])}, Actual: {y_test[i]}")
